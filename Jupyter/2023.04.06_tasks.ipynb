# %%
import pandas

# %%
import numpy as np

# %%
# 1 Load a dataset using Pandas and perform data cleaning operations such as removing null values, 
#removing duplicates,number format etc.

# %%
import statistics

# %%
data = pandas.read_csv("C:\\Users\\gatis\\Desktop\\Marta_macibas\\RigaTechGirl\\Materiali_Python\\penguins_size.csv")

# %%
data
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm
# 0    Adelie  Torgersen              39.1             18.7              181.0  \
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 3    Adelie  Torgersen               NaN              NaN                NaN
# 4    Adelie  Torgersen              36.7             19.3              193.0
# ..      ...        ...               ...              ...                ...
# 339  Gentoo     Biscoe               NaN              NaN                NaN
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
data.drop_duplicates().dropna()
# Out:
#     species     island  culmen_length_mm  culmen_depth_mm  flipper_length_mm
# 0    Adelie  Torgersen              39.1             18.7              181.0  \
# 1    Adelie  Torgersen              39.5             17.4              186.0
# 2    Adelie  Torgersen              40.3             18.0              195.0
# 4    Adelie  Torgersen              36.7             19.3              193.0
# 5    Adelie  Torgersen              39.3             20.6              190.0
# ..      ...        ...               ...              ...                ...
# 338  Gentoo     Biscoe              47.2             13.7              214.0
# 340  Gentoo     Biscoe              46.8             14.3              215.0
# 341  Gentoo     Biscoe              50.4             15.7              222.0
# 342  Gentoo     Biscoe              45.2             14.8              212.0
# 343  Gentoo     Biscoe              49.9             16.1              213.0
#
#      body_mass_g     sex
# ...

# %%
# 2 Use Pandas to calculate summary statistics for a dataset, such as mean, median, and standard deviation.

# %%
data["flipper_length_mm"].mean()
# Out:
# 200.91520467836258

# %%
data["flipper_length_mm"].median()
# Out:
# 197.0

# %%
data["flipper_length_mm"].std()
# Out:
# 14.061713679356888

# %%
#3 Create a scatter plot using Matplotlib to visualize the relationship between two variables in a dataset.

# %%
import matplotlib.pyplot as plot
import pandas

# %%
data = pandas.read_csv("C:\\Users\\gatis\\Desktop\\Marta_macibas\\RigaTechGirl\\Materiali_Python\\penguins_size.csv")
plot.scatter(data['species'], data['body_mass_g'])
plot.xlabel('Penguins species')
plot.ylabel('Penguins body mass in g')
plot.title('Penguins body mass per species')
plot.show()

# %%
#4 Use Pandas to group the data by a categorical variable and calculate summary statistics for each group.

# %%
import statistics
import numpy as np

# %%
group=data.groupby(['species'])

# %%
data.species.nunique()
# Out:
# 3

# %%
group["flipper_length_mm"].mean()
# Out:
# species
# Adelie       189.953642
# Chinstrap    195.823529
# Gentoo       217.186992
# Name: flipper_length_mm, dtype: float64

# %%
group["flipper_length_mm"].min()
# Out:
# species
# Adelie       172.0
# Chinstrap    178.0
# Gentoo       203.0
# Name: flipper_length_mm, dtype: float64

# %%
group["flipper_length_mm"].max()
# Out:
# species
# Adelie       210.0
# Chinstrap    212.0
# Gentoo       231.0
# Name: flipper_length_mm, dtype: float64

# %%
group["flipper_length_mm"].std()
# Out:
# species
# Adelie       6.539457
# Chinstrap    7.131894
# Gentoo       6.484976
# Name: flipper_length_mm, dtype: float64

# %%
# 5 Create a line chart using Matplotlib to visualize the trend of a variable over time.

# %%
# 6 Use Pandas to merge two datasets together based on a common key (try this function - merge(table1, table2, on='Column1', how='inner')

# %%
data2=pandas.read_csv("C:\\Users\\gatis\\Desktop\\Marta_macibas\\RigaTechGirl\\Materiali_Python\\penguins_lter.csv")

# %%
data2
# Out:
#     studyName  Sample Number                              Species  Region
# 0     PAL0708              1  Adelie Penguin (Pygoscelis adeliae)  Anvers  \
# 1     PAL0708              2  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 2     PAL0708              3  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 3     PAL0708              4  Adelie Penguin (Pygoscelis adeliae)  Anvers
# 4     PAL0708              5  Adelie Penguin (Pygoscelis adeliae)  Anvers
# ..        ...            ...                                  ...     ...
# 339   PAL0910            120    Gentoo penguin (Pygoscelis papua)  Anvers
# 340   PAL0910            121    Gentoo penguin (Pygoscelis papua)  Anvers
# 341   PAL0910            122    Gentoo penguin (Pygoscelis papua)  Anvers
# 342   PAL0910            123    Gentoo penguin (Pygoscelis papua)  Anvers
# 343   PAL0910            124    Gentoo penguin (Pygoscelis papua)  Anvers
#
#         island               Stage Individual ID Clutch Completion
# ...

# %%
merged_data=pandas.merge(data2, data, on="island", how="inner")

# %%
merged_data
# Out:
#       studyName  Sample Number                                    Species
# 0       PAL0708              1        Adelie Penguin (Pygoscelis adeliae)  \
# 1       PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 2       PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 3       PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# 4       PAL0708              1        Adelie Penguin (Pygoscelis adeliae)
# ...         ...            ...                                        ...
# 46299   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
# 46300   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
# 46301   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
# 46302   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
# 46303   PAL0910             68  Chinstrap penguin (Pygoscelis antarctica)
#
#        Region     island               Stage Individual ID Clutch Completion
# ...

# %%
# 7 Create a box plot to visualize the distribution of a variable across different categories

# %%
data.boxplot(column=['culmen_length_mm','culmen_depth_mm','flipper_length_mm'])
# Out:
# <Axes: >

# %%
# 8 Create a histogram using Matplotlib to visualize the distribution of a variable in a dataset

# %%
plot.hist(data['flipper_length_mm'])
# Out:
# (array([ 3., 22., 52., 79., 44., 15., 42., 42., 28., 15.]),
#  array([172. , 177.9, 183.8, 189.7, 195.6, 201.5, 207.4, 213.3, 219.2,
#         225.1, 231. ]),
#  <BarContainer object of 10 artists>)
