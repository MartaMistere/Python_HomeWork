# %%
from bs4 import BeautifulSoup

# %%
with open ("Wikipedia_test2.html","r",encoding="utf8") as f:
    data_html=f.read()

soup = BeautifulSoup(data_html,"html.parser")

# %%
soup
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <!-- saved from url=(0054)https://en.wikipedia.org/wiki/List_of_sovereign_states -->
# <html class="client-js vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-language-alert-in-sidebar-enabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-enabled vector-feature-main-menu-pinned-disabled vector-feature-limited-width-enabled vector-feature-limited-width-content-enabled vector-feature-zebra-design-disabled ve-available vector-animations-ready" dir="ltr" lang="en">
#  <head>
#   <meta content="text/html; charset=utf-8" http-equiv="Content-Type"/>
#   <title>
#    List of sovereign states - Wikipedia
#   </title>
#   <script>
# ...

# %%
state_list=soup.find(class_="sortable wikitable jquery-tablesorter")

# %%
print(state_list)
# Out:
# <table class="sortable wikitable jquery-tablesorter">
# <thead><tr>
# <th class="headerSort" data-ol-has-click-handler="" role="columnheader button" style="width:300pt;" tabindex="0" title="Sort ascending">Common and formal names
# </th>
# <th class="headerSort" data-ol-has-click-handler="" role="columnheader button" style="width:150pt;" tabindex="0" title="Sort ascending">Membership within the <a href="https://en.wikipedia.org/wiki/United_Nations_System" title="United Nations System">UN System</a><sup class="reference" id="cite_ref-7"><a data-ol-has-click-handler="" href="https://en.wikipedia.org/wiki/List_of_sovereign_states#cite_note-7">[c]</a></sup>
# </th>
# <th class="headerSort" data-ol-has-click-handler="" role="columnheader button" style="width:150pt;" tabindex="0" title="Sort ascending">Sovereignty dispute<sup class="reference" id="cite_ref-8"><a data-ol-has-click-handler="" href="https://en.wikipedia.org/wiki/List_of_sovereign_states#cite_note-8">[d]</a></sup>
# </th>
# ...

# %%
state=soup.find_all(string="Afghanistan")

# %%
state
# Out:
# ['Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan',
#  'Afghanistan']

# %%
Parent_tag=state[0].parent
print(Parent_tag)
# Out:
# <a href="https://en.wikipedia.org/wiki/Afghanistan" title="Afghanistan">Afghanistan</a>

# %%
Name_tag=Parent_tag.find("a href")
print(Name_tag)
# Out:
# None
